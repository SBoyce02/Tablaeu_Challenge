# %%
import pandas as pd

# %%
# File to Load (Remember to Change These)
file_to_load = "tableau_data.csv"

# Read Purchasing File and store into Pandas data frame
bike_df= pd.read_csv(file_to_load)
# Out:
# C:\Users\roeck\anaconda3\envs\Pythondata\lib\site-packages\IPython\core\interactiveshell.py:2714: DtypeWarning: Columns (0,3,5,6,7,9,10,11,13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
bike_df.head(10)
# Out:
#   tripduration                 starttime                  stoptime  \
# 0          226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1          377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2          288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3          435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4          231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# 5          437  2020-01-01 00:47:21.0850  2020-01-01 00:54:38.7460
# 6          438  2020-01-01 00:59:19.6180  2020-01-01 01:06:38.4200
# 7          403  2020-01-01 00:59:31.5680  2020-01-01 01:06:15.3510
# 8          395  2020-01-01 00:59:34.4200  2020-01-01 01:06:10.2390
# 9          423  2020-01-01 00:59:39.4200  2020-01-01 01:06:42.8380
#
#   start station id          start station name start station latitude  \
# 0             3186               Grove St PATH      40.71958611647166
# 1             3186               Grove St PATH      40.71958611647166
# ...

# %%
bike_gender_df= bike_df.loc[bike_df.gender == 0, 'gender'] = 'Unknown'
bike_gender_df
# Out:
# 'Unknown'

# %%
bike_gender_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-1bf91d7f601f> in <module>()
# ----> 1 bike_gender_df.head(10)
#
# AttributeError: 'str' object has no attribute 'head'
